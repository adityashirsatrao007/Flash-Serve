# %% [markdown]
# # ⚡ Flash-Serve Demo
#
# This notebook allows you to run the **Flash-Serve** high-throughput inference engine directly in Google Colab.
#
# We will:
# 1. Clone the repository.
# 2. Install dependencies.
# 3. Run the Benchmark script to see the speedup (Continuous Batching vs Naive).

# %%
# 1. Clone Repository
# !git clone https://github.com/adityashirsatrao007/Flash-Serve.git
# %cd Flash-Serve

# %%
# 2. Install Dependencies
# !pip install -r requirements.txt
# !pip install pyngrok # For potential UI tunneling

# %% [markdown]
# ## 🚀 Run Performance Benchmark

# %%
# Run the benchmark script to compare performance
# !python scripts/benchmark_plot.py

# %% [markdown]
# ## 🖥️ Run Streamlit UI (Optional)
# To view the UI, you need a tunnel. This example runs the backend and frontend in the background.
